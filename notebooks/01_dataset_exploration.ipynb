# %% [markdown]
# # LEDGAR Dataset Exploration
#
# This placeholder notebook is intentionally minimal. The production workflow lives in scripts and package modules so the project remains reproducible outside notebooks.
